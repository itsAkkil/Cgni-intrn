# %% [markdown]
# ⭐Cognifyz Technologies :  Internship

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#importing sone essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Dataset .csv')

# %% [markdown]
# file imported successfully

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.describe().columns
# Out:
# Index(['Restaurant ID', 'Country Code', 'Longitude', 'Latitude',
#        'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes'],
#       dtype='object')

# %% [markdown]
# # Data set Insights
#
# Quantitative :
#
# 'Restaurant ID', 'Country Code', 'Longitude','Latitude','Average Cost for two', 'Price range', 'Aggregate rating', 'Votes'
#
# 8 columns
#
# Total columns - 21
#
# No Nan values

# %% [markdown]
# # **Task: Predict Restauront Rating**

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
y = df['Aggregate rating']
X = df.drop(['Aggregate rating','Restaurant Name','Address', 'City','City', 'Address',
       'Locality', 'Locality Verbose', 'Cuisines', 'Currency'],axis=1)

# %%
X.head()
# Out:
#    Restaurant ID  Country Code   Longitude   Latitude  Average Cost for two  \
# 0        6317637           162  121.027535  14.565443                  1100
# 1        6304287           162  121.014101  14.553708                  1200
# 2        6300002           162  121.056831  14.581404                  4000
# 3        6318506           162  121.056475  14.585318                  1500
# 4        6314302           162  121.057508  14.584450                  1500
#
#   Has Table booking Has Online delivery Is delivering now  \
# 0               Yes                  No                No
# 1               Yes                  No                No
# 2               Yes                  No                No
# 3                No                  No                No
# 4               Yes                  No                No
#
#   Switch to order menu  Price range Rating color Rating text  Votes
# 0                   No            3   Dark Green   Excellent    314
# ...

# %%
ol=pd.get_dummies(X,dtype=float)

# %%
# ## OLS Linear Regression
import statsmodels.api as sm

# %%
print(sm.OLS(y,ol).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       Aggregate rating   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.986
# Method:                 Least Squares   F-statistic:                 4.619e+04
# Date:                Wed, 24 Jul 2024   Prob (F-statistic):               0.00
# Time:                        09:36:33   Log-Likelihood:                 3003.9
# No. Observations:                9551   AIC:                            -5976.
# Df Residuals:                    9535   BIC:                            -5861.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Restaurant ID            1.827e-09   2.38e-10      7.662      0.000    1.36e-09    2.29e-09
# ...

# %% [markdown]
# **From ols report we can clearly saw that some features can we remove**.
#
# These functions are:
#
# Longitude
#
# Average Cost for two

# %%
ol.drop(['Longitude','Average Cost for two'],axis=1,inplace=True)

# %%
print(sm.OLS(y,ol).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       Aggregate rating   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.986
# Method:                 Least Squares   F-statistic:                 5.330e+04
# Date:                Wed, 24 Jul 2024   Prob (F-statistic):               0.00
# Time:                        09:38:21   Log-Likelihood:                 3003.8
# No. Observations:                9551   AIC:                            -5980.
# Df Residuals:                    9537   BIC:                            -5879.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Restaurant ID             1.83e-09   2.36e-10      7.755      0.000    1.37e-09    2.29e-09
# ...

# %%
## Lets do some viualization
import seaborn as sns
sns.pairplot(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2529)

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

import statsmodels.api as sm

# %%
categorical_cols = X.select_dtypes(include=['object','bool']).columns

# %%
numerical_cols = X.select_dtypes(include=['int64','float64']).columns

# %%
ohe = OneHotEncoder(drop='first')

# %%
ss = StandardScaler()

# %%
preprocessor=ColumnTransformer(transformers=[("num",ss,numerical_cols), ("cat",ohe,categorical_cols),])

# %%
model = Pipeline(steps=[("data_prep", preprocessor ), ("Linear_class",LinearRegression() )])

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('data_prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['Restaurant ID', 'Country Code', 'Longitude', 'Latitude',
#        'Average Cost for two', 'Price range', 'Votes'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   Index(['Has Table booking', 'Has Online delivery', 'Is delivering now',
#        'Switch to order menu', 'Rating color', 'Rating text'],
#       dtype='object'))])),
#                 ('Linear_class', LinearRegression())])

# %%
lr_sml=model.fit(X_train, y_train)

# %%
lr_sml.score(X_test,y_test)
# Out:
# 0.986181313374144

# %%
y_pred= model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error

# %%
## Performance Metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 0.031470307587766824
# 0.12901839698586365
# 0.17739872487638356

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
#display adjusted R-squared
print(1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
# Out:
# 0.986181313374144
# 0.9860866149418108
